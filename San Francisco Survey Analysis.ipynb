# %% [markdown]
# <h1>San Francisco: Public Space, Film Sight, & 311 Corelation </h1>

# %% [markdown]
# <h2>Data Cleanup Draft</h2>

# %%
#Import Dependencies
import pandas as pd
import numpy as np
import json
import requests

# %%
#File paths
film_file_path = 'Resources/Film_Locations_in_San_Francisco_20240116.csv'

#API
api_311 = 'https://data.sfgov.org/resource/vw6y-z8j6.json'
geojson_Public_Spaces = 'https://data.sfgov.org/resource/65ik-7wqd.geojson'

# %%
#Create Dataframes from resource files
film_df = pd.read_csv(film_file_path)
film_df.head()
# Out:
#                   Title  Release Year  \
# 0  Experiment in Terror          1962
# 1  Experiment in Terror          1962
# 2       Chan is Missing          1982
# 3      A View to a Kill          1985
# 4      The Californians          2005
#
#                                            Locations Fun Facts  \
# 0        The Sea Captain's Chest (Fisherman's Wharf)       NaN
# 1                             100 St. Germain Avenue       NaN
# 2  Li Po (916 Grant Avenue at Washington, Chinatown)       NaN
# 3   Taylor and Jefferson Streets (Fisherman's Wharf)       NaN
# 4                                                NaN       NaN
#
#               Production Company                   Distributor  \
# 0  Columbia Pictures Corporation             Columbia Pictures
# 1  Columbia Pictures Corporation             Columbia Pictures
# 2               New Yorker Films              New Yorker Films
# 3            Metro-Goldwyn Mayer  MGM/UA Entertainment Company
# 4            Parker Film Company             Fabrication Films
#
#           Director                                Writer      Actor 1  \
# 0    Blake Edwards                           The Gordons   Glenn Ford
# 1    Blake Edwards                           The Gordons   Glenn Ford
# 2       Wayne Wang                            Wayne Wang     Wood Moy
# 3        John Glen                       Richard Maibaum  Roger Moore
# 4  Jonathan Parker  Jonathan Parker & Catherine DiNapoli    Noah Wyle
#
#               Actor 2          Actor 3  SF Find Neighborhoods  \
# 0          Lee Remick  Stefanie Powers                   99.0
# 1          Lee Remick  Stefanie Powers                   47.0
# 2        Marc Hayashi      Lauren Chew                  104.0
# 3  Christopher Walken    Tanya Roberts                   99.0
# 4                 NaN              NaN                   21.0
#
#    Analysis Neighborhoods  Current Supervisor Districts
# 0                    23.0                           3.0
# 1                    38.0                           8.0
# 2                     6.0                           3.0
# 3                    23.0                           3.0
# 4                    36.0                          10.0

# %%
#Get access to URL to obtain API data
response_311 = requests.get(api_311).json()
df_311 = pd.DataFrame(response_311)
df_311.head()
# Out:
#   service_request_id       requested_datetime         updated_datetime  \
# 0           17769123  2024-01-15T01:35:28.000  2024-01-15T01:35:58.000
# 1           17769120  2024-01-15T01:33:31.000  2024-01-15T01:33:59.000
# 2           17769119  2024-01-15T01:32:11.000  2024-01-15T01:32:14.000
# 3           17769118  2024-01-15T01:29:29.000  2024-01-15T01:29:59.000
# 4           17769117  2024-01-15T01:29:02.000  2024-01-15T01:29:58.000
#
#   status_description status_notes            agency_responsible  \
# 0               Open         open          Recology_Overflowing
# 1               Open         open          Recology_Overflowing
# 2               Open         open  Entertainment Commission - G
# 3               Open         open          Recology_Overflowing
# 4               Open         open          Recology_Overflowing
#
#                    service_name               service_subtype  \
# 0  Street and Sidewalk Cleaning  City_garbage_can_overflowing
# 1  Street and Sidewalk Cleaning  City_garbage_can_overflowing
# 2                  Noise Report                 entertainment
# 3  Street and Sidewalk Cleaning  City_garbage_can_overflowing
# 4  Street and Sidewalk Cleaning  City_garbage_can_overflowing
#
#                 service_details  \
# 0  City_garbage_can_overflowing
# 1  City_garbage_can_overflowing
# 2  Noise Report - entertainment
# 3  City_garbage_can_overflowing
# 4  City_garbage_can_overflowing
#
#                                          address  ...  \
# 0   993 NORTH POINT ST, SAN FRANCISCO, CA, 94109  ...
# 1       690 STANYAN ST, SAN FRANCISCO, CA, 94117  ...
# 2         3159 16TH ST, SAN FRANCISCO, CA, 94103  ...
# 3  106 WEST PORTAL AVE, SAN FRANCISCO, CA, 94127  ...
# 4          6 CLEARY CT, SAN FRANCISCO, CA, 94109  ...
#
#   :@computed_region_fcz8_est8 :@computed_region_nqbw_i6c3  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   :@computed_region_9jxd_iqea closed_date media_url  \
# 0                         NaN         NaN       NaN
# 1                         NaN         NaN       NaN
# 2                         NaN         NaN       NaN
# 3                         NaN         NaN       NaN
# 4                         NaN         NaN       NaN
#
#   :@computed_region_6ezc_tdp2 :@computed_region_h4ep_8xdi  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   :@computed_region_n4xg_c4py :@computed_region_2dwj_jsy4  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   :@computed_region_y6ts_4iup
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 48 columns]

# %%
#Use this for nested JSONs
#Get data from API via request
response_public = requests.get(geojson_Public_Spaces).json()

#Finding the length of the json request
end_range = len(response_public['features'])

#Create list to obtain data from loop
public_space_dict = []

#Loop through json by length
for i in range(end_range):
    public_space_dict.append({'Name':response_public['features'][i]['properties']['name'],
                              'Hours':response_public['features'][i]['properties']['hours_type'],
                              'Year Opened':response_public['features'][i]['properties']['year'],
                              'Food Onsite':response_public['features'][i]['properties']['food_service'],
                              'Restrooms':response_public['features'][i]['properties']['restrooms'],
                              'Address':response_public['features'][i]['properties']['popos_address'],
                              'Capacity':response_public['features'][i]['properties']['seating_no'],
                              'Landscaping':response_public['features'][i]['properties']['landscaping'],
                              'Amenities':response_public['features'][i]['properties']['amenities']})

#Put the JSON data into a pandas dataframe
public_space_df = pd.DataFrame(public_space_dict)
public_space_df.head()
# Out:
#                 Name                Hours Year Opened Food Onsite Restrooms  \
# 0     555 Mission St    Open At All Times        2008         Yes       Yes
# 1  Foundry Square NE    Open At All Times        2008         Yes        No
# 2  Foundry Square SE  Open Business Hours        2005         Yes        No
# 3  Foundry Square NW    Open At All Times        2003         Yes        No
# 4      235 Second St  Open Business Hours        2002         Yes        No
#
#           Address                                           Capacity  \
# 0  555 Mission St                      100 linear seats and benches.
# 1   400 Howard St                        20 linear seats, 24 movable
# 2   405 Howard St  44 movable chairs, 45 linear seats on planter ...
# 3   500 Howard St  44 linear seating on ledges, 21 seating on pla...
# 4   235 Second St                            42 chairs and 15 tables
#
#                                          Landscaping Amenities
# 0                  9 trees, permeable gravel, bushes      None
# 1                                            8 trees      None
# 2                                            8 trees      None
# 3                      8 trees, palm plant planters,      None
# 4  Bamboo and street trees protect space from sid...      None

# %% [markdown]
# <h1>Mapping all locations</h1>

# %%
#Import dependences
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[313], line 2
#       1 #Import dependences
# ----> 2 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'
